# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
#from jupyterthemes import jtplot
from geochemCalc import calcDelta
from crunchTecTools import importTimeSeries, plotBreakthrough
from ipywidgets import widgets
from ipywidgets.widgets import fixed
#jtplot.style()

# %%
os.chdir('/Users/angus/basaltTransformation')

# %%
fileName = 'output.out'

# %%
df, headerNames = importTimeSeries(fileName)
display(headerNames)
# Out:
# ['Time', 'pH', 'Ca++', 'K+', 'SO4--', 'Mg++', 'CO2(aq)']

# %%
topeStd = 0.0212075584
delta = calcDelta(df.loc[:, 'Ca44++'], df.loc[:, 'Ca++'], topeStd)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/Cellar/jupyterlab/2.1.0_1/libexec/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ca44++'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-225663791ce7> in <module>
#       1 topeStd = 0.0212075584
# ----> 2 delta = calcDelta(df.loc[:, 'Ca44++'], df.loc[:, 'Ca++'], topeStd)
#
# /usr/local/Cellar/jupyterlab/2.1.0_1/libexec/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# /usr/local/Cellar/jupyterlab/2.1.0_1/libexec/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# /usr/local/Cellar/jupyterlab/2.1.0_1/libexec/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1387         for i, key in enumerate(tup):
#    1388             if is_label_like(key) or isinstance(key, tuple):
# -> 1389                 section = self._getitem_axis(key, axis=i)
#    1390
#    1391                 # we have yielded a scalar ?
#
# /usr/local/Cellar/jupyterlab/2.1.0_1/libexec/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# /usr/local/Cellar/jupyterlab/2.1.0_1/libexec/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# /usr/local/Cellar/jupyterlab/2.1.0_1/libexec/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3527
#    3528         if axis == 1:
# -> 3529             return self[key]
#    3530
#    3531         self._consolidate_inplace()
#
# /usr/local/Cellar/jupyterlab/2.1.0_1/libexec/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/Cellar/jupyterlab/2.1.0_1/libexec/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ca44++'

# %%
plotVar = widgets.ToggleButtons(
    options=headerNames,
    description='',
    disabled=False,
    button_style='')

widgets.interact(plotBreakthrough, time=fixed(df.loc[:, 'Time']), plotVar=plotVar, dataFrame=fixed(df))
# Out:
# interactive(children=(ToggleButtons(description='plotVar', options=('Time', 'pH', 'Ca++', 'K+', 'SO4--', 'Mg++…
# <function crunchTecTools.plotBreakthrough(time, plotVar, dataFrame)>

# %%
fig, ax = plt.subplots()
ax.plot(df.loc[:, 'Time'], delta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-83c5409d0d67> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.plot(df.loc[:, 'Time'], delta)
#
# NameError: name 'delta' is not defined
